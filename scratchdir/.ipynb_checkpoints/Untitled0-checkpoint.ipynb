# %%
import os

os.chdir("/Users/Dale/Dropbox/code/daleEmotivExperiment/frontend/images2/male_neut")
for file in os.listdir("."):
    print file

target_list = [str(i) + ".jpg" for i in xrange(0,70)]
print "Changing file names..."
i = 0;

file_listing = os.listdir(".");
print "Number of files is %d" % (len(file_listing))

for file in file_listing:
    if file in target_list:
        continue
    while ( (str(i) + ".jpg") in file_listing):
        i += 1
    print "Changing " + file + " to " +  str(i) + ".jpg"
    os.rename(file, str(i) + ".jpg")
    i+= 1

for file in os.listdir("."):
    print file
# Out:
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 31.jpg
# 32.jpg
# 33.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 37.jpg
# 38.jpg
# 39.jpg
# 4.jpg
# 40.jpg
# 41.jpg
# 42.jpg
# 43.jpg
# 44.jpg
# 45.jpg
# 46.jpg
# 47.jpg
# 48.jpg
# 49.jpg
# 5.jpg
# 50.jpg
# 51.jpg
# 52.jpg
# 53.jpg
# 54.jpg
# 55.jpg
# 56.jpg
# 57.jpg
# 58.jpg
# 59.jpg
# 6.jpg
# 60.jpg
# 61.jpg
# 62.jpg
# 63.jpg
# 64.jpg
# 65.jpg
# 66.jpg
# 67.jpg
# 68.jpg
# 69.jpg
# 7.jpg
# 70.jpg
# 8.jpg
# 9.jpg
# Changing file names...
# Number of files is 70
# Changing 70.jpg to 0.jpg
# 0.jpg
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 31.jpg
# 32.jpg
# 33.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 37.jpg
# 38.jpg
# 39.jpg
# ...
